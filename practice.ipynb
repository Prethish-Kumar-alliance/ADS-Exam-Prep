# %%
def prims(adjmatrix):
    vertex = len(adjmatrix)
    largenum = float('inf')
    selectedvertex = [False for i in range(vertex)]
    mstmatrix = [[0 for _ in range(vertex)] for _ in range(vertex)]

    selectedvertex[0] = True

    while False in selectedvertex:
        minimum = largenum
        start = -1
        end = -1

        for i in range(vertex):
            if selectedvertex[i]:
                for j in range(vertex):
                    while not selectedvertex[j] and adjmatrix[i][j] > 0:
                        if adjmatrix[i][j] < minimum:
                            minimum = adjmatrix[i][j]
                            start,end = i,j
        
        if start != -1 and end != -1:
            selectedvertex[end] = True
            mstmatrix[i][j] = minimum
            mstmatrix[j][i] = minimum

    return mstmatrix

# %%
class Graph:
    def __init__(self,vertex):
        self.vertex = vertex
        self.edges = []

    def add_edges(self, vi,vj,wt):
        self.edges.append([vi,vj,wt])

    def search(self,parent, i):
        if parent[i] == i:
            return i
        return self.search(parent, parent[i])
    
    def dounion(self,parents,rank,a,b):
        root_a = self.search(parents,a)
        root_b = self.search(parents,b)

        if rank[root_a] < rank[root_b]:
            parents[root_a] = root_b
        elif rank[root_a] > rank[root_b]:
            parents[root_b] = root_b
        else:
            parents[root_b] = root_a
            rank[root_a] += 1


    def kruskal(self):
        mst = []
        i, e = 0,0 
        self.edges = sorted(self.edges, key= lambda element:element[2])
        parents = []
        rank = []

        for node in range(self.vertex):
            parents.append(node)
            rank.append(0)

        while e < self.vertex - 1 and i < len(self.edges):
            vi, vj, wt = self.edges[i]
            i += 1
            a = self.search(parents,vi)
            b = self.search(parents,vj)

            if a != b:
                e+= 1
                mst.append([vi,vj,wt])
                self.dounion(parents,rank,a,b)
        minCost = 0

        print("MST Edges:")
        for vi,vj,wt in mst:
            print(f'{vi} -> {vj} = wt')
            minCost += wt
        print(f" minCost = {minCost}")

# %%
class Graph:
    def __init__(self,size =0):
        self.size = size
        self.items = [[0 for i in range(self.size)] for j in range(self.size)]
        
    def isempty(self):
        return self.size == 0

    def inser_vertex(self):
        for i in range(self.size):
            self.items[i].append(0)
        self.items.append([0 for j in range(self.size + 1)])
        self.size += 1

    def insert_edge(self, vi,vj):
        if vi >= self.size or vj >= self.size:
            print("Nah")
            return

        self.items[vi][vj] = 1
        self.items[vj][vi] = 1

    def delete_vertext(self, v):
        if v >= self.size:
            print("nah")
        
        for i in range(self.size):
            del self.items[i][v]
        del self.items[v]
        self.size -= 1


    def delete_edge(self,vi,vj):
        if vi >= self.size or vj >= self.size:
            print("Nah")

        self.items[vi][vj] = 0 
        self.items[vj][vi] = 0 

    
    def display(self):
        for i in range(self.size):
            print(f'V{i} |', end='')
            for j in range(self.size):
                print(self.items[i][j], end=" ")
            print("|")
    

    def dfs(self,start,visited = None):
        if visited is None:
            visited = [False for _ in range(self.size)]
        visited[start] = True

        for i in range(self.size):
            if self.items[start][i] == 1 and not visited[i]:
                self.dfs(i,visited)


    def bfs(self,start):
        visited = [False for _ in range(self.size)]
        queue = []
        visited[start] = True
        queue.append(start)

        while queue:
            vertex = queue.pop(0)
            print(vertex)

            for i in range(self.size):
                if self.items[vertex][i] == 1 and not visited[i]:
                    visited[i] = True
                    queue.append(i)

# %%
# Bubble Sort

def bubble(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0,n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr

arr = [64, 34, 25, 12, 22, 11, 90]
print(bubble(arr))
# Out:
# [11, 12, 22, 25, 34, 64, 90]

# %%
#  Selection Sort

def selection(arr):
    n = len(arr)
    for i in range(n):
        min_val = i
        for j in range(i+1,n):
            if arr[j] < arr[min_val]:
                min_val = j
        arr[i], arr[min_val] = arr[min_val] , arr[i]

    return arr


arr = [64, 34, 25, 12, 22, 11, 90]
print(selection(arr))
# Out:
# [11, 12, 22, 25, 34, 64, 90]

# %%
# Insertion

def insertion(arr):
    for i in range(1,len(arr)):
        key = arr[i]
        j = i -1

        while j >= 0 and arr[j] > key:
            arr[j+1] = arr[j]
            j -=1

        arr[j+1] = key

    return arr

arr = [64, 34, 25, 12, 22, 11, 90]
print(insertion(arr))
# Out:
# [11, 12, 22, 25, 34, 64, 90]

# %%
def quick_sort(arr):
    n = len(arr)

    if n <= 1:
        return arr 

    pivot = arr[n // 2]

    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)


arr = [64, 34, 25, 12, 22, 11, 90]
print(quick_sort(arr))
# Out:
# [11, 12, 22, 25, 34, 64, 90]

# %%
def merge_sort(arr):

    n = len(arr)

    if n <= 1:
        return arr
    
    mid = n // 2

    left = merge_sort(arr[:mid])
    right = merge_sort(arr[mid:])

    return merge(left,right)


def merge(left, right):
    result = []
    i, j = 0, 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])

    return result





arr = [64, 34, 25, 12, 22, 11, 90]
print(merge_sort(arr))
# Out:
# [11, 12, 22, 25, 34, 64, 90]

# %%
def heap_sort(arr):
    n = len(arr)

    for i in range(n//2 - 1, -1,-1):
        heapify(arr,n,i)

    for i in range(n-1,0, -1):
        arr[i], arr[0] = arr[0], arr[i]
        heapify(arr,i,0)

    return arr

def heapify(arr,n,i):
    largest = i
    left = 2* i + 1
    right = 2* i + 1

    if left < n and arr[left] > arr[largest]:
        largest = left

    if right < n and arr[right] > arr[largest]:
        largest = right

    if largest != i:
        arr[i], arr[largest] = arr[largest], arr[i]
        heapify(arr,n,largest) 


arr = [64, 34, 25, 12, 22, 11, 90]
print(heap_sort(arr))
# Out:
# [11, 25, 12, 22, 34, 90, 64]

# %%
class StackNode:
    def __init__(self,data,link= None):
        self.data  = data
        self.next = link

class Stack:
    def __init__(self):
        self.top = None
        self.size = 0


    def isempty(self):
        return self.top is None

    def push(self, data):
        newNode = StackNode(data)

        if self.top is not None:
            newNode.next = self.top
            self.top = newNode
        else:
            self.top = newNode

        self.size += 1

    def pop(self):
        self.top = self.top.next
        self.size -= 1

    def peek(self):
        return self.top.data
    
    def get_size(self):
        return self.size
    
    def display(self):
        curNode = self.top
        while curNode is not None:
            print(curNode.data, end='->')
            curNode = curNode.next
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 class StackNode(self,data,link):
#       2     self.data = data
#
# NameError: name 'self' is not defined

# %%
class QueueNode:
    def __init__(self,data,link= None):
        self.data = data
        self.next = link

class Queue:
    def __init__(self):
        self.front = None
        self.rear = None

    def isempty(self):
        return self.front is None

    def enqueue(self,data):
        newNode = QueueNode(data)

        if not self.front:
            self.front = self.rear = newNode
        else:
            self.rear.next = newNode
            self.rear = newNode

    def dequeu(self):
        if not self.front:
            print("Nah")
            return
        
        else:
            data = self.front.data
            if self.front == self.rear:
                self.front = self.rear = None
            else:
                self.front = self.front.next

            return data

# %%
class TreeNode:
    def __init__(self,Data = None, lchild = None, rchild = None):
        self.left = lchild
        self.data = Data
        self.right = rchild

class BST:
    def __init__(self):
        self.root = None

    def insert(self,data):
        newNode = TreeNode(data)

        if self.root is None:
            self.root = newNode

        else:
            curNode = self.root
            parentNode = None

            while curNode is not None:
                parentNode = curNode

                if data < curNode.data:
                    curNode = curNode.left

                elif data > curNode.data:
                    curNode = curNode.right

            if data < parentNode.data:
                parentNode.left = newNode
            else:
                parentNode.right = newNode
    
    def findparent(self,key):
        parent = None
        curNode = self.root

        while curNode is not None:
            if key == curNode.data:
                return parent, curNode
            
            elif key < curNode.data:
                parent = curNode
                curNode = curNode.left

            elif key > curNode.data:
                parent = curNode
                curNode = curNode.right

            return parent
        
    def search
